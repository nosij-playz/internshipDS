# %%
import pandas as pd

# %%
ab=[
['a','b','c'],['e','f','g'],['h','i','j']
]
pd.DataFrame(ab)
# Out:
#    0  1  2
# 0  a  b  c
# 1  e  f  g
# 2  h  i  j

# %%
ab={
'Name':['a','b','c'],'Address':['e','f','g'],'Value':['h','i','j']
}
df=pd.DataFrame(ab)

# %%
print(df)
# Out:
#   Name Address Value
# 0    a       e     h
# 1    b       f     i
# 2    c       g     j

# %%
df[['Name','Address']]
# Out:
#   Name Address
# 0    a       e
# 1    b       f
# 2    c       g

# %%
df['Address']+['  ']+df['Value']
# Out:
# 0    e  h
# 1    f  i
# 2    g  j
# dtype: object

# %%
df.iloc[0:2,0:2]
# Out:
#   Name Address
# 0    a       e
# 1    b       f

# %%
df.head()
# Out:
#   Name Address Value
# 0    a       e     h
# 1    b       f     i
# 2    c       g     j

# %%
df.head(3)
# Out:
#   Name Address Value
# 0    a       e     h
# 1    b       f     i
# 2    c       g     j

# %%
df.tail(2)
# Out:
#   Name Address Value
# 1    b       f     i
# 2    c       g     j

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Address  3 non-null      object
#  2   Value    3 non-null      object
# dtypes: object(3)
# memory usage: 204.0+ bytes

# %%
df.columns
# Out:
# Index(['Name', 'Address', 'Value'], dtype='object')

# %%
df.loc[0:2,'Name']
# Out:
# 0    a
# 1    b
# 2    c
# Name: Name, dtype: object

# %%
df.shape
# Out:
# (3, 3)

# %%
df.shape[0]
# Out:
# 3

# %%
df['Name']=='a'
# Out:
# 0     True
# 1    False
# 2    False
# Name: Name, dtype: bool

# %%
df[df['Name']=='a']
# Out:
#   Name Address Value
# 0    a       e     h

# %%
df['Name'].value_counts()
# Out:
# Name
# a    1
# b    1
# c    1
# Name: count, dtype: int64

# %%
df['Name'].value_counts().index
# Out:
# Index(['a', 'b', 'c'], dtype='object', name='Name')

# %%
df['Name'].value_counts().values
# Out:
# array([1, 1, 1])

# %%
df.isna()
# Out:
#     Name  Address  Value
# 0  False    False  False
# 1  False    False  False
# 2  False    False  False

# %%
df.isna().sum()
# Out:
# Name       0
# Address    0
# Value      0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#   Name Address Value
# 0    a       e     h
# 1    b       f     i
# 2    c       g     j

# %%
df.dropna()
# Out:
#   Name Address Value
# 0    a       e     h
# 1    b       f     i
# 2    c       g     j

# %%
df.drop(0,inplace=True)

# %%
df.drop('Value',axis=1)
# Out:
#   Name Address
# 1    b       f
# 2    c       g

# %%
df
# Out:
#   Name Address Value
# 1    b       f     i
# 2    c       g     j

# %%
df['numeric']=[1,2]

# %%
df['numeric'].mean()
df['numeric'].median()
df['numeric'].mode()
# Out:
# 0    1
# 1    2
# Name: numeric, dtype: int64

# %%
for i in df.columns:
    print(i)
# Out:
# Name
# Address
# Value
# numeric

# %%
for i in df.columns:
    print(df[i].mode())
# Out:
# 0    b
# 1    c
# Name: Name, dtype: object
# 0    f
# 1    g
# Name: Address, dtype: object
# 0    i
# 1    j
# Name: Value, dtype: object
# 0    1
# 1    2
# Name: numeric, dtype: int64

# %%
df['numeric'].quantile(0.25)
# Out:
# np.float64(1.25)

# %%
df['numeric'].mean()
# Out:
# np.float64(1.5)

# %%
df.dtypes
# Out:
# Name       object
# Address    object
# Value      object
# numeric     int64
# dtype: object

# %%
import numpy as np

# %%
df.index
# Out:
# RangeIndex(start=1, stop=3, step=1)

# %%
df.loc[4]=np.array(['a','c','t',4])

# %%
df['numeric'].astype(int)
# Out:
# 1    1
# 2    2
# 4    4
# Name: numeric, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 1 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Address  3 non-null      object
#  2   Value    3 non-null      object
#  3   numeric  3 non-null      object
# dtypes: object(4)
# memory usage: 120.0+ bytes

# %%
df['numeric'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df['numeric'].mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# ...

# %%
df.groupby('Name')["numeric"].mean()

# %%
from sklearn.datasets import iris_load
